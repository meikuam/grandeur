# %%
# !pip install Cython
# Out:
# ...
#   Using cached Cython-0.29.32-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.9 MB)
# ...

# %%
# !sudo apt-get install libsndfile1-dev

# %%
# BRANCH = 'main'
# !python -m pip install git+https://github.com/NVIDIA/NeMo.git@$BRANCH#egg=nemo_toolkit[all]
# Out:
# ...
#   Cloning https://github.com/NVIDIA/NeMo.git (to revision main) to /tmp/pip-install-7zx4pren/nemo-toolkit_f69a2357d8d14a4196bdd0032b2e81f2
#   Running command git clone --filter=blob:none --quiet https://github.com/NVIDIA/NeMo.git /tmp/pip-install-7zx4pren/nemo-toolkit_f69a2357d8d14a4196bdd0032b2e81f2
#   Resolved https://github.com/NVIDIA/NeMo.git to commit db234bd6f96fca25b796624715cf0c7b4e146beb
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached setuptools-59.5.0-py3-none-any.whl (952 kB)
# ...
#   Using cached onnx-1.12.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
# ...
#   Using cached wrapt-1.14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (77 kB)
# ...
#   Using cached ruamel.yaml-0.17.21-py3-none-any.whl (109 kB)
# ...
#   Using cached scikit_learn-1.1.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30.5 MB)
# ...

# %%
# !git clone https://github.com/NVIDIA/NeMo && cd NeMo && ./reinstall.sh
# Out:
# Cloning into 'NeMo'...
# remote: Enumerating objects: 122622, done.
# remote: Counting objects: 100% (275/275), done.
# remote: Compressing objects: 100% (157/157), done.
# remote: Total 122622 (delta 156), reused 202 (delta 115), pack-reused 122347
# Receiving objects: 100% (122622/122622), 343.37 MiB | 5.82 MiB/s, done.
# Resolving deltas: 100% (93491/93491), done.
# Updating files: 100% (2544/2544), done.
# Uninstalling stuff
# Found existing installation: nemo-toolkit 1.13.0rc0
# Uninstalling nemo-toolkit-1.13.0rc0:
#   Successfully uninstalled nemo-toolkit-1.13.0rc0
# Found existing installation: sacrebleu 2.2.1
# Uninstalling sacrebleu-2.2.1:
#   Successfully uninstalled sacrebleu-2.2.1
# WARNING: Skipping nemo_asr as it is not installed.
# WARNING: Skipping nemo_nlp as it is not installed.
# WARNING: Skipping nemo_tts as it is not installed.
# WARNING: Skipping nemo_simple_gan as it is not installed.
# WARNING: Skipping nemo_cv as it is not installed.
# ...

# %%
# !pip install numpy==1.21
# !pip install inflect==5.3.0

# %%
import numpy as np
np.__version__
# Out:
# '1.21.0'

# %%
import nemo

# %%
import nemo.collections.asr as nemo_asr
# Out:
# [NeMo W 2022-10-11 21:52:31 optimizers:55] Apex was not found. Using the lamb or fused_adam optimizer will error out.

# %%
nemo_asr.models.EncDecCTCModel.list_available_models()
# Out:
# [PretrainedModelInfo(
#  	pretrained_model_name=QuartzNet15x5Base-En,
#  	description=QuartzNet15x5 model trained on six datasets: LibriSpeech, Mozilla Common Voice (validated clips from en_1488h_2019-12-10), WSJ, Fisher, Switchboard, and NSC Singapore English. It was trained with Apex/Amp optimization level O1 for 600 epochs. The model achieves a WER of 3.79% on LibriSpeech dev-clean, and a WER of 10.05% on dev-other. Please visit https://ngc.nvidia.com/catalog/models/nvidia:nemospeechmodels for further details.,
#  	location=https://api.ngc.nvidia.com/v2/models/nvidia/nemospeechmodels/versions/1.0.0a5/files/QuartzNet15x5Base-En.nemo
#  ),
#  PretrainedModelInfo(
#  	pretrained_model_name=stt_en_quartznet15x5,
#  	description=For details about this model, please visit https://ngc.nvidia.com/catalog/models/nvidia:nemo:stt_en_quartznet15x5,
#  	location=https://api.ngc.nvidia.com/v2/models/nvidia/nemo/stt_en_quartznet15x5/versions/1.0.0rc1/files/stt_en_quartznet15x5.nemo
#  ),
# ...

# %%
#импорт предобученной модели на русском языке, которая дана в репозитории nemo
rus_quartznet = nemo_asr.models.EncDecCTCModel.from_pretrained(model_name='stt_ru_quartznet15x5')
# Out:
# [NeMo I 2022-10-11 21:53:12 cloud:66] Downloading from: https://api.ngc.nvidia.com/v2/models/nvidia/nemo/stt_ru_quartznet15x5/versions/1.0.0rc1/files/stt_ru_quartznet15x5.nemo to /home/user/.cache/torch/NeMo/NeMo_1.12.0/stt_ru_quartznet15x5/92506570b7206ea395e295b3fbbf07e3/stt_ru_quartznet15x5.nemo
# [NeMo I 2022-10-11 21:53:26 common:910] Instantiating model from pre-trained checkpoint
# [NeMo W 2022-10-11 21:53:26 modelPT:142] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     manifest_filepath: /raid/noneval.json
#     sample_rate: 16000
#     labels:
#     - ' '
#     - а
#     - б
#     - в
#     - г
#     - д
#     - е
#     - ё
#     - ж
#     - з
#     - и
#     - й
#     - к
#     - л
#     - м
#     - н
#     - о
#     - п
#     - р
#     - с
#     - т
#     - у
#     - ф
#     - х
#     - ц
#     - ч
#     - ш
#     - щ
#     - ъ
# ...

# %%
from IPython import display

# %%
# !ls ../data/ruLitorchaudio_exploration.ipynbech/ruls_data/dev/audio/5397/2145/poemi_12_pushkin_0000.wav
# Out:
# ls: cannot access '../data/ruLitorchaudio_exploration.ipynbech/ruls_data/dev/audio/5397/2145/poemi_12_pushkin_0000.wav': No such file or directory

# %%
path = "../data/ruLibriSpeech/ruls_data/dev/audio/5397/2145/poemi_12_pushkin_0000.wav"


#Транскрибация
transcribe = rus_quartznet.transcribe(paths2audio_files=[path])
print(transcribe)

display.Audio(path)
# Out:
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# ['поистину еврейки молодой мвнедорого душевное спасенья']

# %%
display.Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
path = "вторник в 22-37.m4a"


transcribe = rus_quartznet.transcribe(paths2audio_files=[path])
print(transcribe)
display.Audio(path)
# Out:
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# ['раз раз привет ранонумонулуздавству те здравстутя']

# %%
path = "../data/ruLibriSpeech/ruls_data/dev/audio/5397/2145/poemi_12_pushkin_0007.wav"


#Транскрибация
transcribe = rus_quartznet.transcribe(paths2audio_files=[path])
print(transcribe)

display.Audio(path)
# Out:
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# ['нет мило то траво обманулось анит себя марию описал']
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
